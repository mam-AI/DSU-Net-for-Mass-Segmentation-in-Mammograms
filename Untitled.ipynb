# %% [markdown]
# # Probando una idea con el codigo de DSU
# La idea en este notebook es ver los elementos basicos para hacer un script de entrenamiento con nuestros datos.
#
# El modelo utiliza un conjunto de imagenes de CBIS-DDSM, pero que al momento de escribir este parrafo aun no logro descargar porque no he visto como instalar su programa que tienen para debian.
# _(lazy deer is lazy)_
#
# **Advertencia a terceros**: Cuando trato de entender codigo tiendo a ser bien casual y algo crudo en el lenguaje. No tomar esta guia como algo muy serio.

# %%
# lets check if this shit explodes then.

from Models.ASPPNet import *

# %%
model = asppnet()

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 256, 256, 1) 0
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 256, 256, 1)  4           input_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 256, 256, 1)  0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 64) 640         activation[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 256, 256, 64) 0           conv2d_1[0][0]
# ...

# %% [markdown]
# Yikes, es un modelo bien grande al parecer. Definitivamente no lo puedo ejecutar en mi PC. Lo bueno es que hay servidores.
#
# Lo bueno es que como retorna literal un `tf.keras.Model`, por lo que el entrenamiento y evaluacion se hace soprendentemente simple.
#
# ## CLAHE?
#
# Al parecer toca ver como implementar el CLAHE, para poder replicar el preprocesamiento de las imagenes.
